# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_valid, X_train = X_train_full[:5_000] / 255, X_train_full[5_000:] / 255
y_valid, y_train = y_train_full[:5_000], y_train_full[5_000:]

class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
model = keras.models.Sequential()

# Preprocess each image by converting it to 1D array
model.add(keras.layers.Flatten(input_shape=[28, 28]))

# Dense hidden layer with 300 neurons
# Each layer manages its own weight matrix containing all connection weights
# between neurons and their inputs
model.add(keras.layers.Dense(300, activation="relu"))

# Second layer with 100 neurons
model.add(keras.layers.Dense(100, activation="relu"))

# Output layer with 10 neurons (one per class) using softmax activation function (classes are exclusive)
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
# Note that Dense layers often have a lot of parameters. For example, the first hidden
# layer has 784 × 300 connection weights, plus 300 bias terms, which adds up to
# 235,500 parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
weights, biases = model.layers[1].get_weights()

# Weights are initialized randomly
weights
# Out:
# array([[ 0.01168192, -0.05692657,  0.03622408, ..., -0.03606072,
#         -0.06958124, -0.05201819],
#        [-0.00889576, -0.02966519,  0.03795449, ...,  0.06232388,
#          0.06698005,  0.06421624],
#        [ 0.06525475,  0.02344125, -0.05535536, ..., -0.03722604,
#          0.0536218 ,  0.00790839],
#        ...,
#        [-0.04792947, -0.05591903, -0.01107784, ..., -0.00965104,
#          0.06095123, -0.01061905],
#        [-0.01057603, -0.02974209,  0.05467021, ...,  0.03052325,
#          0.01555669,  0.01353783],
#        [-0.07141811, -0.01458085,  0.03386119, ...,  0.05181192,
#          0.00810551, -0.04449223]], dtype=float32)

# %%
model.compile(loss="sparse_categorical_crossentropy",
 optimizer="sgd",
 metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.7163 - accuracy: 0.7667 - val_loss: 0.4985 - val_accuracy: 0.8376
# Epoch 2/30
#  - ETA: 0s - loss: 0.4968 - accuracy: 0.8265
# Epoch 3/30
#  - ETA: 0s - loss: 0.4453 - accuracy: 0.8425
# Epoch 4/30
#  - ETA: 0s - loss: 0.4202 - accuracy: 0.8533
# Epoch 5/30
#  - ETA: 0s - loss: 0.3962 - accuracy: 0.8595
# Epoch 6/30
#  - ETA: 0s - loss: 0.3789 - accuracy: 0.8664
# Epoch 7/30
#  - ETA: 0s - loss: 0.3687 - accuracy: 0.8694
# Epoch 8/30
#  - ETA: 0s - loss: 0.3548 - accuracy: 0.8740
# Epoch 9/30
#  - ETA: 0s - loss: 0.3444 - accuracy: 0.8770
# Epoch 10/30
#  - ETA: 0s - loss: 0.3355 - accuracy: 0.8788
# Epoch 11/30
#  - ETA: 0s - loss: 0.3263 - accuracy: 0.8845
# Epoch 12/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3178 - accuracy: 0.8862 - val_loss: 0.3310 - val_accuracy: 0.8836
# Epoch 13/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3115 - accuracy: 0.8883 - val_loss: 0.3263 - val_accuracy: 0.8826
# Epoch 14/30
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3039 - accuracy: 0.8914 - val_loss: 0.3447 - val_accuracy: 0.8748
# Epoch 15/30
#  - ETA: 1s - loss: 0.2903 - accuracy: 0.8955
# Epoch 16/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2925 - accuracy: 0.8943 - val_loss: 0.3168 - val_accuracy: 0.8860
# Epoch 17/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2860 - accuracy: 0.8959 - val_loss: 0.3215 - val_accuracy: 0.8852
# Epoch 18/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2806 - accuracy: 0.8979 - val_loss: 0.3365 - val_accuracy: 0.8782
# Epoch 19/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2754 - accuracy: 0.9008 - val_loss: 0.3145 - val_accuracy: 0.8868
# Epoch 20/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2711 - accuracy: 0.9023 - val_loss: 0.3108 - val_accuracy: 0.8868
# Epoch 21/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2653 - accuracy: 0.9045 - val_loss: 0.3114 - val_accuracy: 0.8840
# Epoch 22/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2606 - accuracy: 0.9056 - val_loss: 0.3091 - val_accuracy: 0.8908
# Epoch 23/30
#  - ETA: 1s - loss: 0.2499 - accuracy: 0.9075
# Epoch 24/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2524 - accuracy: 0.9096 - val_loss: 0.3343 - val_accuracy: 0.8776
# Epoch 25/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2478 - accuracy: 0.9123 - val_loss: 0.3037 - val_accuracy: 0.8876
# Epoch 26/30
#  - ETA: 1s - loss: 0.2401 - accuracy: 0.9141
# Epoch 27/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2406 - accuracy: 0.9136 - val_loss: 0.2997 - val_accuracy: 0.8906
# Epoch 28/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2371 - accuracy: 0.9152 - val_loss: 0.3005 - val_accuracy: 0.8904
# Epoch 29/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2332 - accuracy: 0.9157 - val_loss: 0.3116 - val_accuracy: 0.8888
# Epoch 30/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2291 - accuracy: 0.9173 - val_loss: 0.2931 - val_accuracy: 0.8928

# %%
import pandas as pd
import matplotlib.pyplot as plt

def print_history(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)

print_history(history)

# %%
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
#  - ETA: 0s - loss: 0.2254 - accuracy: 0.9176
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2223 - accuracy: 0.9203 - val_loss: 0.2919 - val_accuracy: 0.8986
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2189 - accuracy: 0.9206 - val_loss: 0.2920 - val_accuracy: 0.9004
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2158 - accuracy: 0.9228 - val_loss: 0.2916 - val_accuracy: 0.8966
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2111 - accuracy: 0.9242 - val_loss: 0.2907 - val_accuracy: 0.8942
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2097 - accuracy: 0.9240 - val_loss: 0.2890 - val_accuracy: 0.8990
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2055 - accuracy: 0.9266 - val_loss: 0.2892 - val_accuracy: 0.8958
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2029 - accuracy: 0.9267 - val_loss: 0.3164 - val_accuracy: 0.8878
# Epoch 9/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1995 - accuracy: 0.9281 - val_loss: 0.3007 - val_accuracy: 0.8934
# Epoch 10/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1958 - accuracy: 0.9301 - val_loss: 0.3055 - val_accuracy: 0.8900

# %%
print_history(history)

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 64.0137 - accuracy: 0.8532
# [64.01367950439453, 0.8532000184059143]

# %%
y_pred = model.predict(X_test[:3])

print(class_names[y_pred[2].argmax()])

plt.imshow(X_test[2])
# Out:
# Trouser
