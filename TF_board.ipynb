# %%
import os

root_logdir = os.path.join(os.curdir, "my_logs")

def get_run_logdir():
 import time

 run_id = time.strftime("run_%Y_%m_%d")

 return os.path.join(root_logdir, run_id)

# %%
from tensorflow import keras

fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test_full, y_test) = fashion_mnist.load_data()

X_valid, X_train = X_train_full[:5_000] / 255, X_train_full[5_000:] / 255
y_valid, y_train = y_train_full[:5_000], y_train_full[5_000:]
X_test = X_test_full / 255

# %%
model = keras.models.Sequential()

model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])

# %%
run_logdir = get_run_logdir()

tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

history = model.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid), callbacks=[tensorboard_cb])

# tensorboard --logdir=./my_logs --port=6006
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.7337 - accuracy: 0.7547 - val_loss: 0.5121 - val_accuracy: 0.8268
# Epoch 2/30
#  - ETA: 0s - loss: 0.4927 - accuracy: 0.8288
# Epoch 3/30
#  - ETA: 1s - loss: 0.4469 - accuracy: 0.8431
# Epoch 4/30
#  - ETA: 0s - loss: 0.4161 - accuracy: 0.8535
# Epoch 5/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3945 - accuracy: 0.8605 - val_loss: 0.3954 - val_accuracy: 0.8638
# Epoch 6/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3787 - accuracy: 0.8669 - val_loss: 0.3927 - val_accuracy: 0.8614
# Epoch 7/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3641 - accuracy: 0.8712 - val_loss: 0.3714 - val_accuracy: 0.8672
# Epoch 8/30
#  - ETA: 0s - loss: 0.3550 - accuracy: 0.8751
# Epoch 9/30
#  - ETA: 1s - loss: 0.3466 - accuracy: 0.8777
# Epoch 10/30
#  - ETA: 1s - loss: 0.3317 - accuracy: 0.8818
# Epoch 11/30
#  - ETA: 0s - loss: 0.3252 - accuracy: 0.8845
# Epoch 12/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3171 - accuracy: 0.8875 - val_loss: 0.3541 - val_accuracy: 0.8734
# Epoch 13/30
#  - ETA: 0s - loss: 0.3099 - accuracy: 0.8894
# Epoch 14/30
#  - ETA: 1s - loss: 0.3038 - accuracy: 0.8923
# Epoch 15/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2966 - accuracy: 0.8939 - val_loss: 0.3380 - val_accuracy: 0.8786
# Epoch 16/30
#  - ETA: 1s - loss: 0.2897 - accuracy: 0.8969
# Epoch 17/30
#  - ETA: 0s - loss: 0.2856 - accuracy: 0.8977
# Epoch 18/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2790 - accuracy: 0.9001 - val_loss: 0.3341 - val_accuracy: 0.8804
# Epoch 19/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2741 - accuracy: 0.9019 - val_loss: 0.3154 - val_accuracy: 0.8832
# Epoch 20/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2688 - accuracy: 0.9031 - val_loss: 0.3225 - val_accuracy: 0.8864
# Epoch 21/30
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.2647 - accuracy: 0.9050 - val_loss: 0.3046 - val_accuracy: 0.8900
# Epoch 22/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2592 - accuracy: 0.9072 - val_loss: 0.3104 - val_accuracy: 0.8850
# Epoch 23/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2539 - accuracy: 0.9093 - val_loss: 0.3012 - val_accuracy: 0.8908
# Epoch 24/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2503 - accuracy: 0.9100 - val_loss: 0.3167 - val_accuracy: 0.8852
# Epoch 25/30
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.2449 - accuracy: 0.9118 - val_loss: 0.3402 - val_accuracy: 0.8784
# Epoch 26/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2413 - accuracy: 0.9132 - val_loss: 0.3024 - val_accuracy: 0.8914
# Epoch 27/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2381 - accuracy: 0.9143 - val_loss: 0.3000 - val_accuracy: 0.8906
# Epoch 28/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2336 - accuracy: 0.9166 - val_loss: 0.3158 - val_accuracy: 0.8836
# Epoch 29/30
#  - ETA: 1s - loss: 0.2220 - accuracy: 0.9181
# Epoch 30/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2266 - accuracy: 0.9190 - val_loss: 0.2966 - val_accuracy: 0.8918
