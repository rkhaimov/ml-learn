# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# %%
from tensorflow import keras

model = keras.models.Sequential([
    # Since the dataset is quite noisy, we just use a single hidden layer
    # with fewer neurons than before, to avoid overfitting
    keras.layers.Dense(40, activation="relu", input_shape=X_train_scaled.shape[1:]),

    # the output layer has a single neuron (since we only want to
    # predict a single value) and uses no activation function
    # and the loss function is the mean squared error
    keras.layers.Dense(1)
])

model.compile(loss="mean_squared_error", optimizer="sgd")

# %%
history = model.fit(X_train_scaled, y_train, epochs=20, validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/20
# 363/363 [==============================] - 1s 1000us/step - loss: 0.7732 - val_loss: 0.6927
# Epoch 2/20
# 363/363 [==============================] - 0s 790us/step - loss: 1.0142 - val_loss: 0.4928
# Epoch 3/20
# 363/363 [==============================] - 0s 748us/step - loss: 0.4639 - val_loss: 0.4463
# Epoch 4/20
# 363/363 [==============================] - 0s 740us/step - loss: 0.4326 - val_loss: 0.4256
# Epoch 5/20
# 363/363 [==============================] - 0s 770us/step - loss: 0.4147 - val_loss: 0.4151
# Epoch 6/20
# 363/363 [==============================] - 0s 728us/step - loss: 0.4086 - val_loss: 0.3966
# Epoch 7/20
# 363/363 [==============================] - 0s 752us/step - loss: 0.3961 - val_loss: 0.3947
# Epoch 8/20
# 363/363 [==============================] - 0s 738us/step - loss: 0.3922 - val_loss: 0.3864
# Epoch 9/20
# 363/363 [==============================] - 0s 748us/step - loss: 0.3915 - val_loss: 0.3838
# Epoch 10/20
# 363/363 [==============================] - 0s 730us/step - loss: 0.3832 - val_loss: 0.3743
# Epoch 11/20
# 363/363 [==============================] - 0s 739us/step - loss: 0.3801 - val_loss: 0.3755
# Epoch 12/20
# 363/363 [==============================] - 0s 749us/step - loss: 0.3779 - val_loss: 0.3807
# Epoch 13/20
# 363/363 [==============================] - 0s 736us/step - loss: 0.3757 - val_loss: 0.3686
# Epoch 14/20
# 363/363 [==============================] - 0s 744us/step - loss: 0.3735 - val_loss: 0.3692
# Epoch 15/20
# 363/363 [==============================] - 0s 779us/step - loss: 0.3703 - val_loss: 0.3608
# Epoch 16/20
# 363/363 [==============================] - 0s 800us/step - loss: 0.3672 - val_loss: 0.3597
# Epoch 17/20
# 363/363 [==============================] - 0s 796us/step - loss: 0.3669 - val_loss: 0.3575
# Epoch 18/20
# 363/363 [==============================] - 0s 754us/step - loss: 0.3631 - val_loss: 0.3592
# Epoch 19/20
# 363/363 [==============================] - 0s 734us/step - loss: 0.3632 - val_loss: 0.3581
# Epoch 20/20
# 363/363 [==============================] - 0s 763us/step - loss: 0.3578 - val_loss: 0.3563

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test_scaled)

print(y_pred[0][0], y_test[0])

mean_squared_error(y_test.reshape(-1, 1), y_pred)
# Out:
# 1.2350572 1.938
# 0.3556423644804147

# %%
input = keras.layers.Input(shape=X_train_scaled.shape[1:])
hidden1 = keras.layers.Dense(30, activation="relu")(input)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.Concatenate()([input, hidden2])
output = keras.layers.Dense(1)(concat)

model = keras.models.Model(inputs=[input], outputs=[output])

# %%
model.compile(loss="mean_squared_error", optimizer="sgd")

# %%
history = model.fit(X_train_scaled, y_train, epochs=50, validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/50
# 363/363 [==============================] - 0s 967us/step - loss: 0.5024 - val_loss: 1.3696
# Epoch 2/50
# 363/363 [==============================] - 0s 881us/step - loss: 0.5290 - val_loss: 0.5323
# Epoch 3/50
# 363/363 [==============================] - 0s 837us/step - loss: 0.4788 - val_loss: 0.5428
# Epoch 4/50
# 363/363 [==============================] - 0s 818us/step - loss: 0.5914 - val_loss: 0.5203
# Epoch 5/50
# 363/363 [==============================] - 0s 835us/step - loss: 0.6568 - val_loss: 0.4966
# Epoch 6/50
# 363/363 [==============================] - 0s 837us/step - loss: 0.4655 - val_loss: 0.4717
# Epoch 7/50
# 363/363 [==============================] - 0s 852us/step - loss: 0.4683 - val_loss: 0.6142
# Epoch 8/50
# 363/363 [==============================] - 0s 887us/step - loss: 0.4626 - val_loss: 0.6532
# Epoch 9/50
# 363/363 [==============================] - 0s 883us/step - loss: 0.4530 - val_loss: 0.5270
# Epoch 10/50
# 363/363 [==============================] - 0s 919us/step - loss: 0.4379 - val_loss: 0.4572
# Epoch 11/50
#  - ETA: 0s - loss: 0.4727
# Epoch 12/50
# 363/363 [==============================] - 0s 832us/step - loss: 1.1531 - val_loss: 0.5700
# Epoch 13/50
# 363/363 [==============================] - 0s 815us/step - loss: 0.4661 - val_loss: 0.6953
# Epoch 14/50
# 363/363 [==============================] - 0s 840us/step - loss: 0.5226 - val_loss: 5.5425
# Epoch 15/50
# 363/363 [==============================] - 0s 886us/step - loss: 1.7455 - val_loss: 61.7434
# Epoch 16/50
# 363/363 [==============================] - 0s 917us/step - loss: 5.2644 - val_loss: 14.2185
# Epoch 17/50
# 363/363 [==============================] - 0s 897us/step - loss: 1.4673 - val_loss: 2.5499
# Epoch 18/50
# 363/363 [==============================] - 0s 862us/step - loss: 4.9558 - val_loss: 0.8433
# Epoch 19/50
# 363/363 [==============================] - 0s 928us/step - loss: 0.5355 - val_loss: 0.6876
# Epoch 20/50
# 363/363 [==============================] - 0s 876us/step - loss: 1.0083 - val_loss: 0.6101
# Epoch 21/50
# 363/363 [==============================] - 0s 905us/step - loss: 0.5243 - val_loss: 0.6290
# Epoch 22/50
# 363/363 [==============================] - 0s 887us/step - loss: 0.5537 - val_loss: 0.5198
# Epoch 23/50
# 363/363 [==============================] - 0s 884us/step - loss: 0.5052 - val_loss: 0.5194
# Epoch 24/50
# 363/363 [==============================] - 0s 840us/step - loss: 0.4987 - val_loss: 0.5651
# Epoch 25/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4685 - val_loss: 0.4960
# Epoch 26/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4582 - val_loss: 0.5963
# Epoch 27/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.7121 - val_loss: 0.4905
# Epoch 28/50
# 363/363 [==============================] - 0s 904us/step - loss: 0.4420 - val_loss: 0.4521
# Epoch 29/50
#  - ETA: 0s - loss: 0.4397
# Epoch 30/50
# 363/363 [==============================] - 0s 903us/step - loss: 0.4272 - val_loss: 0.4634
# Epoch 31/50
# 363/363 [==============================] - 0s 907us/step - loss: 0.4730 - val_loss: 0.4202
# Epoch 32/50
# 363/363 [==============================] - 0s 906us/step - loss: 0.4462 - val_loss: 0.4454
# Epoch 33/50
# 363/363 [==============================] - 0s 885us/step - loss: 0.4231 - val_loss: 0.4148
# Epoch 34/50
# 363/363 [==============================] - 0s 893us/step - loss: 0.4162 - val_loss: 0.4190
# Epoch 35/50
# 363/363 [==============================] - 0s 881us/step - loss: 0.4134 - val_loss: 0.4031
# Epoch 36/50
# 363/363 [==============================] - 0s 909us/step - loss: 0.4093 - val_loss: 0.3957
# Epoch 37/50
# 363/363 [==============================] - 0s 899us/step - loss: 0.4065 - val_loss: 0.3924
# Epoch 38/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4055 - val_loss: 0.3922
# Epoch 39/50
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4066 - val_loss: 0.4023
# Epoch 40/50
# 363/363 [==============================] - 0s 928us/step - loss: 0.4019 - val_loss: 0.3905
# Epoch 41/50
# 363/363 [==============================] - 0s 900us/step - loss: 0.3994 - val_loss: 0.3989
# Epoch 42/50
# 363/363 [==============================] - 0s 860us/step - loss: 0.3995 - val_loss: 0.3889
# Epoch 43/50
# 363/363 [==============================] - 0s 933us/step - loss: 0.4033 - val_loss: 0.3864
# Epoch 44/50
# 363/363 [==============================] - 0s 898us/step - loss: 0.3967 - val_loss: 0.4011
# Epoch 45/50
# 363/363 [==============================] - 0s 886us/step - loss: 0.4208 - val_loss: 0.3894
# Epoch 46/50
# 363/363 [==============================] - 0s 934us/step - loss: 0.4098 - val_loss: 0.3797
# Epoch 47/50
# 363/363 [==============================] - 0s 948us/step - loss: 0.3905 - val_loss: 0.3785
# Epoch 48/50
# 363/363 [==============================] - 0s 917us/step - loss: 0.3932 - val_loss: 0.3719
# Epoch 49/50
# 363/363 [==============================] - 0s 826us/step - loss: 0.3836 - val_loss: 0.3948
# Epoch 50/50
# 363/363 [==============================] - 0s 934us/step - loss: 0.3821 - val_loss: 0.3663

# %%
import pandas as pd

model.evaluate(X_test_scaled, y_test)

pd.DataFrame(history.history).plot(figsize=(8, 8))
# Out:
# 162/162 [==============================] - 0s 604us/step - loss: 0.3775
# <AxesSubplot:>
